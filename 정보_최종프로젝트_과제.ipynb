# %% [markdown]
# <a href="https://colab.research.google.com/github/integeressence/comsci2024-11301-/blob/main/%EC%A0%95%EB%B3%B4_%EC%B5%9C%EC%A2%85%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 평가기준
#
# 0.   **데이터를 본인이 만들었는가?**
# 1. **결과 해석이 신뢰성이 있는가? (논문을 근거해서 해석해야 합니다.)**
# 2. **결과 해석이 의미가 있는가?**
# 3. **결과 해석을 위해 적절한 시각화(그래프)를 하였는가?**
# 4. **보고서는 완성도가 있는가?**
# 5. **프로그램은 완성도가 있는가?**
# 6. **제출 기한을 지켰는가?**

# %% [markdown]
# # 1. 문제 정의

# %% [markdown]
# ### 본 프로젝트는

# %% [markdown]
# #2. 데이터 수집
#
#
# - 수집한 데이터 설명합니다.
# - 데이터 수집 방법을 설명합니다.

# %% [markdown]
# ### 그래프 자료 링크(논문): file:///C:/Users/kangj/Downloads/%E2%80%98%EC%96%B4%EB%A6%B0%EC%9D%B4%E2%80%99%EC%99%80%20%E2%80%98%ED%82%A4%EC%A6%88%E2%80%99%EB%A5%BC%20%EC%A3%BC%EC%A0%9C%EC%96%B4%EB%A1%9C%20%ED%95%98%EB%8A%94%20%EC%9C%A0%ED%8A%9C%EB%B8%8C(YouTube)%20%EC%BD%98%ED%85%90%EC%B8%A0%20%EB%B6%84%EC%84%9D%20LDA%20%ED%86%A0%ED%94%BD%EB%AA%A8%EB%8D%B8%EB%A7%81.pdf

# %% [markdown]
# ### ![Screenshot 2024-06-14 144157.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-06-14 143748.png](data:image/png;base64,...)

# %% [markdown]
# # 3. 데이터 전처리
#
# - 어떤 데이터 전처리를 했는지 설명합니다.
# - 결측값 처리, 중복 제거, 이상치 제거 등
# - **원시 데이터와 전처리 한 데이터 파일은 Git허브에 저장되어 있어야 합니다.**

# %% [markdown]
# # 4. 전체 코드
#
# - **데이터를 읽어 올 때 Git허브에서 읽어와야 합니다.**
# - 코드에 주석을 달아 주세요.

# %%
from google.colab import drive

# Google 드라이브 마운트
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# GitPython 설치 (필요한 경우)
# !pip install gitpython

# GitHub 리포지토리 클론
import git

# 클론할 리포지토리 URL
repo_url = "https://github.com/integeressence/comsci2024-11301-.git"

# 리포지토리를 클론할 디렉토리 (디폴트: 현재 디렉토리)
clone_dir = "/content/your-repo"

# 리포지토리 클론
git.Repo.clone_from(repo_url, clone_dir)

# 디렉토리 이동
import os
os.chdir(clone_dir)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 5. 데이터 시각화
#
# - 그래프 3개 이상
# - 사용한 그래프를 왜 사용했는지 이유를 설명합니다.

# %% [markdown]
# # 6. 결과 해석방법
#
# - 참고한 논문의 내용과 내가 분석한 내용이 비교가 될 수 있도록 합니다.

# %% [markdown]
# # 7. 참고 문헌
#
# - 사용한 논문, 사이트를 넣어 주세요.
# - **참고문헌 작성법을 꼭 찾아보고 넣어 주세요.**

# %% [markdown]
# # 8. 챗Gpt 사용 공유 링크

# %% [markdown]
# ## 링크:

# %% [markdown]
# # 9. 프로젝트를 하면서 느낀점
#
# - 5줄 이상

# %% [markdown]
# # 프로젝트를 하면서 굉장히 큰
